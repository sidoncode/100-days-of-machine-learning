# %% [markdown]
# <a href="https://colab.research.google.com/github/sidoncode/100-days-of-machine-learning/blob/main/upgrad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello1")
# Out:
# hello1

# %%
# importing Libraries

# importing pandas as pd
import pandas as pd

# importing numpy as np

# for Mathematical calculations
import numpy as np

# importing pyplot from matplotlib as plt
# for plotting graphs
import matplotlib.pyplot as plt # used for ploting the graph
plt.style.use('default')
# %matplotlib inline

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-1c23fe37-0bfb-4e0a-99fd-48dc4e14b504" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c23fe37-0bfb-4e0a-99fd-48dc4e14b504">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving RELIANCE.NS.csv to RELIANCE.NS.csv

# %%
# importing time-series data -  before doing any operations in the csv-file, we need to import it!
reliance = pd.read_csv('RELIANCE.NS.csv', index_col='Date',parse_dates=True)

# Printing dataFrame
reliance.head() #.head-> first 5 rows .tail -> last 5 rows
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-07-21  507.192322  507.687622  497.781525  498.450195  485.688568
# 2016-07-22  498.276825  504.121429  497.831055  502.660278  489.790863
# 2016-07-25  502.239258  507.068512  498.945496  506.573181  493.603546
# 2016-07-26  506.697021  512.541626  502.833649  507.217102  494.231049
# 2016-07-27  506.721771  508.182922  499.737976  501.793488  488.946259
#
#                Volume
# Date
# 2016-07-21  3097170.0
# 2016-07-22  3184126.0
# 2016-07-25  3803482.0
# 2016-07-26  4853316.0
# 2016-07-27  5090697.0

# %%
reliance.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-07-14  2100.350098  2106.850098  2081.250000  2086.000000  2086.000000
# 2021-07-15  2095.000000  2095.000000  2078.500000  2082.350098  2082.350098
# 2021-07-16  2087.750000  2114.750000  2087.600098  2112.399902  2112.399902
# 2021-07-19  2100.000000  2124.000000  2092.250000  2098.949951  2098.949951
# 2021-07-20  2099.500000  2108.000000  2084.000000  2093.800049  2093.800049
#
#                Volume
# Date
# 2021-07-14  3937768.0
# 2021-07-15  4360415.0
# 2021-07-16  4074206.0
# 2021-07-19  3855577.0
# 2021-07-20  3110610.0

# %%
# updating our dataFrame to have only
# one column 'Close' as rest all columns
# are of no use for us at the moment
# using .to_frame() to convert pandas series
# into dataframe.
reliance = reliance['Close'].to_frame()

# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 30
reliance['SMA30'] = reliance['Close'].rolling(30).mean()

# removing all the NULL values using
# dropna() method -> drop null values 
reliance.dropna(inplace= True)

# %%
# printing Dataframe
reliance
# we have removed the null values -> thats the reason the number of rows got decreased!
# Out:
#                   Close        SMA30
# Date
# 2016-01-09   509.767914   505.689072
# 2016-02-09   501.917328   505.804643
# 2016-06-09   505.161560   505.888019
# 2016-07-09   504.047150   505.803818
# 2016-08-09   511.848175   505.958187
# ...                 ...          ...
# 2021-07-14  2086.000000  2160.583325
# 2021-07-15  2082.350098  2156.339998
# 2021-07-16  2112.399902  2153.736662
# 2021-07-19  2098.949951  2149.454997
# 2021-07-20  2093.800049  2145.428328
#
# [1145 rows x 2 columns]

# %%
# plotting Close price and simple
# moving average of 30 days using .plot() method -> mathplotlib library one of the method
reliance[['Close', 'SMA30']].plot(label='RELIANCE',
								figsize=(16, 8))

# SMA - Simple Moving Average with windows size -  30
# blue is the Closing Price of the stock - at the particular time interval

# %%
# importing Libraries

# importing pandas as pd
import pandas as pd

# importing numpy as np
# for Mathematical calculations
import numpy as np

# importing pyplot from matplotlib as plt
# for plotting graphs
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
# importing time-series data
reliance = pd.read_csv('RELIANCE.NS.csv',
					index_col='Date',
					parse_dates=True)

# Printing dataFrame
reliance.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-07-21  507.192322  507.687622  497.781525  498.450195  485.688568
# 2016-07-22  498.276825  504.121429  497.831055  502.660278  489.790863
# 2016-07-25  502.239258  507.068512  498.945496  506.573181  493.603546
# 2016-07-26  506.697021  512.541626  502.833649  507.217102  494.231049
# 2016-07-27  506.721771  508.182922  499.737976  501.793488  488.946259
#
#                Volume
# Date
# 2016-07-21  3097170.0
# 2016-07-22  3184126.0
# 2016-07-25  3803482.0
# 2016-07-26  4853316.0
# 2016-07-27  5090697.0

# %%
# this is the average trading volumes
# mean -average value

df2 = reliance["Volume"].mean()
print(df2)
# Out:
# 10451418.901785715

# %%
reliance['open-close']=reliance['Close'] - reliance['Open']
print(reliance)
# new col -> open - close( profit or loss) --> non - absolute value - negative and postive
# if( value of(open - close ) > 0) -> profit
# if( value of(open - close ) < 0) -> loss
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-07-21   507.192322   507.687622   497.781525   498.450195   485.688568
# 2016-07-22   498.276825   504.121429   497.831055   502.660278   489.790863
# 2016-07-25   502.239258   507.068512   498.945496   506.573181   493.603546
# 2016-07-26   506.697021   512.541626   502.833649   507.217102   494.231049
# 2016-07-27   506.721771   508.182922   499.737976   501.793488   488.946259
# ...                 ...          ...          ...          ...          ...
# 2021-07-14  2100.350098  2106.850098  2081.250000  2086.000000  2086.000000
# 2021-07-15  2095.000000  2095.000000  2078.500000  2082.350098  2082.350098
# 2021-07-16  2087.750000  2114.750000  2087.600098  2112.399902  2112.399902
# 2021-07-19  2100.000000  2124.000000  2092.250000  2098.949951  2098.949951
# 2021-07-20  2099.500000  2108.000000  2084.000000  2093.800049  2093.800049
#
#                Volume  open-close
# Date
# ...

# %%
# updating our dataFrame to have only
# one column 'Close' as rest all columns
# are of no use for us at the moment
# using .to_frame() to convert pandas series
# into dataframe.
reliance = reliance['Close'].to_frame()

# calculating cumulative moving
# average using .expanding().mean()
reliance['CMA30'] = reliance['Close'].expanding().mean()
# CMA - 30 -> Cumulative moving Average with the window size  -30
# printing Dataframe
reliance
# Out:
#                   Close        CMA30
# Date
# 2016-07-21   498.450195   498.450195
# 2016-07-22   502.660278   500.555236
# 2016-07-25   506.573181   502.561218
# 2016-07-26   507.217102   503.725189
# 2016-07-27   501.793488   503.338849
# ...                 ...          ...
# 2021-07-14  2086.000000  1232.000327
# 2021-07-15  2082.350098  1232.692231
# 2021-07-16  2112.399902  1233.407440
# 2021-07-19  2098.949951  1234.110562
# 2021-07-20  2093.800049  1234.808362
#
# [1234 rows x 2 columns]

# %%
# plotting Close price and cumulative moving
# average of 30 days using .plot() method
reliance[['Close', 'CMA30']].plot(label='RELIANCE',
								figsize=(16, 8))
